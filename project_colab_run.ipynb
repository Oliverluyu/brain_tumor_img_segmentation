# %%
# !git clone https://github.com/Oliverluyu/brain_tumor_img_segmentation.git
# Out:
# Cloning into 'brain_tumor_img_segmentation'...
# remote: Enumerating objects: 13529, done.
# remote: Counting objects: 100% (380/380), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 13529 (delta 196), reused 332 (delta 180), pack-reused 13149
# Receiving objects: 100% (13529/13529), 1.33 GiB | 15.00 MiB/s, done.
# Resolving deltas: 100% (750/750), done.
# Updating files: 100% (15736/15736), done.

# %%
# !pip install einops
# %cd brain_tumor_img_segmentation
# !git checkout master
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 940.8 kB/s eta 0:00:00
# ...
# /content/brain_tumor_img_segmentation
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %% [markdown]
# ## Unet (Tumour Only) Segmentation

# %%
# !python training.py -c Configs/seg_vanilla_unet_tumourOnly.json
# Out:
# 100% 95/95 [00:37<00:00,  2.53it/s]
# Epoch: 1; train loss: 0.4195; validation loss: 0.3856
# 100% 95/95 [00:35<00:00,  2.71it/s]
# Epoch: 2; train loss: 0.0840; validation loss: 0.0594
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 3; train loss: 0.0475; validation loss: 0.0442
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 4; train loss: 0.0404; validation loss: 0.0407
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 5; train loss: 0.0342; validation loss: 0.0348
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 6; train loss: 0.0312; validation loss: 0.0350
# 100% 95/95 [00:35<00:00,  2.69it/s]
# Epoch: 7; train loss: 0.0279; validation loss: 0.0312
# 100% 95/95 [00:35<00:00,  2.69it/s]
# Epoch: 8; train loss: 0.0257; validation loss: 0.0301
# 100% 95/95 [00:35<00:00,  2.66it/s]
# Epoch: 9; train loss: 0.0233; validation loss: 0.0299
# 100% 95/95 [00:35<00:00,  2.66it/s]
# Epoch: 10; train loss: 0.0217; validation loss: 0.0297
# 100% 95/95 [00:35<00:00,  2.69it/s]
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240414-034953_with_tumOnly.png?raw=1)

# %% [markdown]
# ### Unet (Tumour Only) Segmentation Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_tumourOnly_test.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_3.png
# Average IoU for the test set: 0.4089
# Average F1 Score for the test set: 0.4973
# Average Precision: 0.6005
# Average Recall/Sensitivity: 0.4661
# Average Specificity: 0.9860
# Average F1 Score: 0.4973

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_3.png?raw=1)

# %% [markdown]
# ## Unet (Tumour and non-Tomour) Segmentation

# %%
# !python training.py -c Configs/seg_vanilla_unet.json
# Out:
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 1; train loss: 0.2269; validation loss: 0.1572
# 100% 133/133 [00:46<00:00,  2.88it/s]
# Epoch: 2; train loss: 0.0464; validation loss: 0.0394
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 3; train loss: 0.0330; validation loss: 0.0328
# 100% 133/133 [00:46<00:00,  2.87it/s]
# Epoch: 4; train loss: 0.0283; validation loss: 0.0288
# 100% 133/133 [00:46<00:00,  2.86it/s]
# Epoch: 5; train loss: 0.0254; validation loss: 0.0262
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 6; train loss: 0.0237; validation loss: 0.0256
# 100% 133/133 [00:46<00:00,  2.86it/s]
# Epoch: 7; train loss: 0.0218; validation loss: 0.0247
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 8; train loss: 0.0200; validation loss: 0.0239
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 9; train loss: 0.0178; validation loss: 0.0254
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 10; train loss: 0.0163; validation loss: 0.0238
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240413-153903_without_tf_lrn.png?raw=1)

# %% [markdown]
# ### Unet (Tumour and non-Tomour) Segmentation Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_3.png
# Average IoU for the test set: 0.5995
# Average F1 Score for the test set: 0.4340
# Average Precision: 0.6286
# Average Recall/Sensitivity: 0.4469
# Average Specificity: 0.9979
# Average F1 Score: 0.4340

# %% [markdown]
# picture illustration
#
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_notum.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_notum.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_notum.pth_3.png?raw=1)

# %% [markdown]
# ## Unet Classification on Brain Tumor MRI Dataset Training

# %%
# !git pull
# !python training.py -c Configs/cls_vanilla_unet_gated.json
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 328 bytes | 328.00 KiB/s, done.
# From https://github.com/Oliverluyu/brain_tumor_img_segmentation
#    3f666fe..8736a3a  exp2_new   -> origin/exp2_new
# Updating 3f666fe..8736a3a
# Fast-forward
#  Configs/cls_vanilla_unet_gated.json | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Epoch: 1; train loss: 1.1863; validation loss: 0.5570
# Validation Accuracy: 79.25%
# Epoch: 2; train loss: 0.6399; validation loss: 0.6515
# Validation Accuracy: 74.76%
# Epoch: 3; train loss: 0.5490; validation loss: 0.5186
# Validation Accuracy: 79.61%
# Epoch: 4; train loss: 0.4861; validation loss: 0.4216
# Validation Accuracy: 84.22%
# Epoch: 5; train loss: 0.4509; validation loss: 0.3907
# Validation Accuracy: 85.56%
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240413-150120_classification.png?raw=1)

# %% [markdown]
# ## Unet (Tumour Only) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_vanilla_unet_tumourOnly_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240414-073250.png?raw=1)

# %% [markdown]
# ### Unet (Tumour Only) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_tumourOnly_transLearn_cls_layer_test.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.3855
# Average F1 Score for the test set: 0.4638
# Average Precision: 0.5921
# Average Recall/Sensitivity: 0.4420
# Average Specificity: 0.9867
# Average F1 Score: 0.4638

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_3.png?raw=1)

# %% [markdown]
# ## Unet (Tumour and non-Tomour) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240413-234842_with_tf_lrn_layer.png?raw=1)

# %% [markdown]
# ### Unet (Tumour and non-Tomour) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.6506
# Average F1 Score for the test set: 0.4775
# Average Precision: 0.5824
# Average Recall/Sensitivity: 0.4675
# Average Specificity: 0.9989
# Average F1 Score: 0.4775

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png?raw=1)

# %% [markdown]
# ## Attention Unet (Tumour and non-Tomour) Segmentation

# %%
# !python training.py -c Configs/seg_unet_attention.json
# Out:
# 100% 133/133 [00:52<00:00,  2.56it/s]
# Epoch: 1; train loss: 0.3295; validation loss: 0.1892
# 100% 133/133 [00:51<00:00,  2.60it/s]
# Epoch: 2; train loss: 0.0530; validation loss: 0.0401
# 100% 133/133 [00:51<00:00,  2.58it/s]
# Epoch: 3; train loss: 0.0367; validation loss: 0.0340
# 100% 133/133 [00:51<00:00,  2.56it/s]
# Epoch: 4; train loss: 0.0308; validation loss: 0.0321
# 100% 133/133 [00:51<00:00,  2.57it/s]
# Epoch: 5; train loss: 0.0273; validation loss: 0.0275
# 100% 133/133 [00:51<00:00,  2.58it/s]
# Epoch: 6; train loss: 0.0254; validation loss: 0.0265
# 100% 133/133 [00:51<00:00,  2.59it/s]
# Epoch: 7; train loss: 0.0238; validation loss: 0.0247
# 100% 133/133 [00:51<00:00,  2.58it/s]
# Epoch: 8; train loss: 0.0212; validation loss: 0.0260
# 100% 133/133 [00:51<00:00,  2.57it/s]
# Epoch: 9; train loss: 0.0192; validation loss: 0.0240
# 100% 133/133 [00:51<00:00,  2.59it/s]
# Epoch: 10; train loss: 0.0191; validation loss: 0.0246
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240414-071852.png?raw=1)

# %% [markdown]
# ### Attention Unet (Tumour and non-Tomour) Segmentation

# %%
# !python testing.py -c Configs/seg_unet_attention.json
# Out:
# Saved visualization to saved_models/Attention_unet_best_segmentation.pth_1.png
# Saved visualization to saved_models/Attention_unet_best_segmentation.pth_2.png
# Saved visualization to saved_models/Attention_unet_best_segmentation.pth_3.png
# Average IoU for the test set: 0.6060
# Average F1 Score for the test set: 0.4472
# Average Precision: 0.5675
# Average Recall/Sensitivity: 0.4490
# Average Specificity: 0.9981
# Average F1 Score: 0.4472

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation.pth_3.png?raw=1)

# %% [markdown]
# ## Attention Unet (Tumour and non-Tomour) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_unet_attention_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ![alt text](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/model_performance_20240414-040747.jpeg?raw=1)

# %% [markdown]
# ### Attention Unet (Tumour and non-Tomour) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_unet_attention_transLearn_cls_layer.json
# Out:
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.6902
# Average F1 Score for the test set: 0.5218
# Average Precision: 0.5911
# Average Recall/Sensitivity: 0.5105
# Average Specificity: 0.9990
# Average F1 Score: 0.5218

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png?raw=1)

# %% [markdown]
# Multi-head Attention Unet (Tumour and Non-tumour) Segmentation

# %%
# !pip install einops

# %%
# !python training.py -c Configs/seg_unet_multihead_attention.json
# Out:
# 100% 399/399 [03:14<00:00,  2.05it/s]
# Epoch: 1; train loss: 0.0999; validation loss: 0.0417
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 2; train loss: 0.0339; validation loss: 0.0315
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 3; train loss: 0.0278; validation loss: 0.0264
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 4; train loss: 0.0242; validation loss: 0.0244
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 5; train loss: 0.0210; validation loss: 0.0244
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 6; train loss: 0.0182; validation loss: 0.0209
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 7; train loss: 0.0167; validation loss: 0.0195
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 8; train loss: 0.0142; validation loss: 0.0192
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 9; train loss: 0.0124; validation loss: 0.0210
# 100% 399/399 [03:17<00:00,  2.02it/s]
# Epoch: 10; train loss: 0.0107; validation loss: 0.0209
# ...

# %%
# !python testing.py -c Configs/seg_unet_multihead_attention.json
# Out:
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation.pth_1.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation.pth_2.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation.pth_3.png
# Average IoU for the test set: 0.6820
# Average F1 Score for the test set: 0.5301
# Average Precision: 0.5466
# Average Recall/Sensitivity: 0.5760
# Average Specificity: 0.9972

# %% [markdown]
# picture illustration
# ![Original Image](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Multihead_attention_unet_best_segmentation.pth_1.png?raw=1) ![Ground Truth Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Multihead_attention_unet_best_segmentation.pth_2.png?raw=1) ![Predicted Mask](https://github.com/Oliverluyu/brain_tumor_img_segmentation/blob/master/saved_models/Multihead_attention_unet_best_segmentation.pth_3.png?raw=1)

# %% [markdown]
# classification based on multihead

# %%
# !python training.py -c Configs/cls_multihead_attention_unet_gated.json
# Out:
# Epoch: 1; train loss: 0.0771; validation loss: 0.0001
# Validation Accuracy: 100.00%
# Epoch: 2; train loss: 0.0045; validation loss: 0.0000
# Validation Accuracy: 100.00%
# Epoch: 3; train loss: 0.0025; validation loss: 0.0000
# Validation Accuracy: 100.00%
# Figure(1000x500)
# Plot saved to saved_models/model_performance_20240422-134702.png
# Training of  classification  is finished!!!

# %% [markdown]
# ![alt text](saved_models/model_performance_20240422-134702.png)

# %%
# !python training.py -c Configs/seg_unet_multihead_attention_transferLrn.json
# Out:
# applying transfer learning
# Transferred layer init_conv.weight
# Transferred layer init_conv.bias
# Transferred layer downs.0.0.block1.proj.weight
# Transferred layer downs.0.0.block1.proj.bias
# Transferred layer downs.0.0.block1.norm.weight
# Transferred layer downs.0.0.block1.norm.bias
# Transferred layer downs.0.0.block2.proj.weight
# Transferred layer downs.0.0.block2.proj.bias
# Transferred layer downs.0.0.block2.norm.weight
# Transferred layer downs.0.0.block2.norm.bias
# Transferred layer downs.0.1.block1.proj.weight
# Transferred layer downs.0.1.block1.proj.bias
# Transferred layer downs.0.1.block1.norm.weight
# Transferred layer downs.0.1.block1.norm.bias
# Transferred layer downs.0.1.block2.proj.weight
# Transferred layer downs.0.1.block2.proj.bias
# Transferred layer downs.0.1.block2.norm.weight
# Transferred layer downs.0.1.block2.norm.bias
# Transferred layer downs.0.2.fn.fn.to_qkv.weight
# Transferred layer downs.0.2.fn.fn.to_out.0.weight
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240427-120959.png)

# %%
# !python testing.py -c Configs/seg_unet_multihead_attention_transferLrn.json
# Out:
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_1.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_2.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_3.png
# Average IoU for the test set: 0.6537
# Average F1 Score for the test set: 0.4724
# Average Precision: 0.5731
# Average Recall/Sensitivity: 0.4481
# Average Specificity: 0.9986

# %% [markdown]
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_1.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_2.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn.pth_3.png)

# %%
# !python training.py -c Configs/seg_unet_multihead_attention_transferLrn_w_mid.json
# Out:
# applying transfer learning
# Transferred layer init_conv.weight
# Transferred layer init_conv.bias
# Transferred layer downs.0.0.block1.proj.weight
# Transferred layer downs.0.0.block1.proj.bias
# Transferred layer downs.0.0.block1.norm.weight
# Transferred layer downs.0.0.block1.norm.bias
# Transferred layer downs.0.0.block2.proj.weight
# Transferred layer downs.0.0.block2.proj.bias
# Transferred layer downs.0.0.block2.norm.weight
# Transferred layer downs.0.0.block2.norm.bias
# Transferred layer downs.0.1.block1.proj.weight
# Transferred layer downs.0.1.block1.proj.bias
# Transferred layer downs.0.1.block1.norm.weight
# Transferred layer downs.0.1.block1.norm.bias
# Transferred layer downs.0.1.block2.proj.weight
# Transferred layer downs.0.1.block2.proj.bias
# Transferred layer downs.0.1.block2.norm.weight
# Transferred layer downs.0.1.block2.norm.bias
# Transferred layer downs.0.2.fn.fn.to_qkv.weight
# Transferred layer downs.0.2.fn.fn.to_out.0.weight
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240427-132806.png)

# %%
# !python testing.py -c Configs/seg_unet_multihead_attention_transferLrn_w_mid.json
# Out:
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_1.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_2.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_3.png
# Average IoU for the test set: 0.6540
# Average F1 Score for the test set: 0.4781
# Average Precision: 0.5553
# Average Recall/Sensitivity: 0.4591
# Average Specificity: 0.9984

# %% [markdown]
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_1.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_2.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_transferlrn_w_mid.pth_3.png)

# %%
# !python training.py -c Configs/seg_unet_multihead_attention_transferLrn_freeze_20loops.json
# Out:
# applying transfer learning
# Transferred layer init_conv.weight
# Transferred layer init_conv.bias
# Transferred layer downs.0.0.block1.proj.weight
# Transferred layer downs.0.0.block1.proj.bias
# Transferred layer downs.0.0.block1.norm.weight
# Transferred layer downs.0.0.block1.norm.bias
# Transferred layer downs.0.0.block2.proj.weight
# Transferred layer downs.0.0.block2.proj.bias
# Transferred layer downs.0.0.block2.norm.weight
# Transferred layer downs.0.0.block2.norm.bias
# Transferred layer downs.0.1.block1.proj.weight
# Transferred layer downs.0.1.block1.proj.bias
# Transferred layer downs.0.1.block1.norm.weight
# Transferred layer downs.0.1.block1.norm.bias
# Transferred layer downs.0.1.block2.proj.weight
# Transferred layer downs.0.1.block2.proj.bias
# Transferred layer downs.0.1.block2.norm.weight
# Transferred layer downs.0.1.block2.norm.bias
# Transferred layer downs.0.2.fn.fn.to_qkv.weight
# Transferred layer downs.0.2.fn.fn.to_out.0.weight
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240427-142209.png)

# %%
# !python testing.py -c Configs/seg_unet_multihead_attention_transferLrn_freeze_20loops.json
# Out:
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_1.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_2.png
# Saved visualization to saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_3.png
# Average IoU for the test set: 0.5918
# Average F1 Score for the test set: 0.4077
# Average Precision: 0.4756
# Average Recall/Sensitivity: 0.3976
# Average Specificity: 0.9985

# %% [markdown]
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_1.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_2.png)
# ![alt text](saved_models/Multihead_attention_unet_best_segmentation_tf_freeze_20.pth_3.png)

# %% [markdown]
# gradually  Gradual Unfreezing

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_gradually_unfreeze.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_gradually_unfreeze.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_3.png
# Traceback (most recent call last):
#   File "/content/brain_tumor_img_segmentation/testing.py", line 156, in <module>
#     main(args.config)
#   File "/content/brain_tumor_img_segmentation/testing.py", line 117, in main
#     iou = calculate_iou(pred, msk)
#   File "/content/brain_tumor_img_segmentation/testing.py", line 20, in calculate_iou
#     return iou.item()
# KeyboardInterrupt

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze1.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze1.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze1.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze1.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze1.pth_3.png
# Average IoU for the test set: 0.6638
# Average F1 Score for the test set: 0.5495
# Average Precision: 0.6215
# Average Recall/Sensitivity: 0.5554
# Average Specificity: 0.9982

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze2.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze2.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze2.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze2.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze2.pth_3.png
# Average IoU for the test set: 0.6796
# Average F1 Score for the test set: 0.5281
# Average Precision: 0.6198
# Average Recall/Sensitivity: 0.5268
# Average Specificity: 0.9986

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze3.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze3.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze3.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze3.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze3.pth_3.png
# Average IoU for the test set: 0.6915
# Average F1 Score for the test set: 0.5286
# Average Precision: 0.5261
# Average Recall/Sensitivity: 0.5521
# Average Specificity: 0.9978

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze4.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_partial_freeze4.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze4.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze4.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_partial_freeze4.pth_3.png
# Average IoU for the test set: 0.6258
# Average F1 Score for the test set: 0.4555
# Average Precision: 0.5594
# Average Recall/Sensitivity: 0.4969
# Average Specificity: 0.9980

# %%
# !pip install einops
# !git clone https://github.com/Oliverluyu/brain_tumor_img_segmentation.git
# %cd brain_tumor_img_segmentation
# !git checkout gradually_unfreezing
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 450.7 kB/s eta 0:00:00
# ...
# Cloning into 'brain_tumor_img_segmentation'...
# remote: Enumerating objects: 13560, done.
# remote: Counting objects: 100% (411/411), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 13560 (delta 215), reused 378 (delta 215), pack-reused 13149
# Receiving objects: 100% (13560/13560), 1.41 GiB | 36.32 MiB/s, done.
# Resolving deltas: 100% (769/769), done.
# Updating files: 100% (15748/15748), done.
# /content/brain_tumor_img_segmentation
# Branch 'gradually_unfreezing' set up to track remote branch 'gradually_unfreezing' from 'origin'.
# Switched to a new branch 'gradually_unfreezing'

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_gradually_unfreeze.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_gradually_unfreeze.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_gradually_unfreeze.pth_3.png
# Average IoU for the test set: 0.5752
# Average F1 Score for the test set: 0.4035
# Average Precision: 0.4807
# Average Recall/Sensitivity: 0.4054
# Average Specificity: 0.9987

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_3layer.json
# Out:
# applying transfer learning
# Caught this error when initialized pretrained model: AttributeError("'X' object has no attribute 'frozen_layers'")
# 100% 133/133 [00:48<00:00,  2.75it/s]
# Epoch: 1; train loss: 0.2678; validation loss: 0.1628
# 100% 133/133 [00:48<00:00,  2.76it/s]
# Epoch: 2; train loss: 0.1316; validation loss: 0.1147
# 100% 133/133 [00:47<00:00,  2.79it/s]
# Epoch: 3; train loss: 0.1011; validation loss: 0.0883
# 100% 133/133 [00:47<00:00,  2.78it/s]
# Epoch: 4; train loss: 0.0805; validation loss: 0.0764
# 100% 133/133 [00:49<00:00,  2.71it/s]
# Epoch: 5; train loss: 0.0675; validation loss: 0.0628
# 100% 133/133 [00:49<00:00,  2.68it/s]
# Epoch: 6; train loss: 0.0568; validation loss: 0.0542
# 100% 133/133 [00:49<00:00,  2.67it/s]
# Epoch: 7; train loss: 0.0487; validation loss: 0.0473
# 100% 133/133 [00:49<00:00,  2.69it/s]
# Epoch: 8; train loss: 0.0423; validation loss: 0.0475
# 100% 133/133 [00:49<00:00,  2.68it/s]
# ...

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer_3layer.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_3layer.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_3layer.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer_3layer.pth_3.png
# Average IoU for the test set: 0.7068
# Average F1 Score for the test set: 0.5426
# Average Precision: 0.5611
# Average Recall/Sensitivity: 0.5447
# Average Specificity: 0.9983
