# %%
# !git clone https://github.com/Oliverluyu/brain_tumor_img_segmentation.git
# Out:
# Cloning into 'brain_tumor_img_segmentation'...
# remote: Enumerating objects: 13327, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 13327 (delta 89), reused 159 (delta 72), pack-reused 13149
# Receiving objects: 100% (13327/13327), 651.32 MiB | 32.38 MiB/s, done.
# Resolving deltas: 100% (643/643), done.
# Updating files: 100% (15655/15655), done.

# %%
# %cd brain_tumor_img_segmentation
# !git checkout exp2_new
# Out:
# /content/brain_tumor_img_segmentation
# Branch 'exp2_new' set up to track remote branch 'exp2_new' from 'origin'.
# Switched to a new branch 'exp2_new'

# %%
# !git pull
# !python training.py -c Configs/cls_vanilla_unet_gated.json
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 328 bytes | 328.00 KiB/s, done.
# From https://github.com/Oliverluyu/brain_tumor_img_segmentation
#    3f666fe..8736a3a  exp2_new   -> origin/exp2_new
# Updating 3f666fe..8736a3a
# Fast-forward
#  Configs/cls_vanilla_unet_gated.json | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Epoch: 1; train loss: 1.1863; validation loss: 0.5570
# Validation Accuracy: 79.25%
# Epoch: 2; train loss: 0.6399; validation loss: 0.6515
# Validation Accuracy: 74.76%
# Epoch: 3; train loss: 0.5490; validation loss: 0.5186
# Validation Accuracy: 79.61%
# Epoch: 4; train loss: 0.4861; validation loss: 0.4216
# Validation Accuracy: 84.22%
# Epoch: 5; train loss: 0.4509; validation loss: 0.3907
# Validation Accuracy: 85.56%
# ...

# %% [markdown]
# ## Unet (Tumour Only) Segmentation

# %%
# !python training.py -c Configs/seg_vanilla_unet_tumourOnly.json
# Out:
# 100% 95/95 [00:37<00:00,  2.53it/s]
# Epoch: 1; train loss: 0.4195; validation loss: 0.3856
# 100% 95/95 [00:35<00:00,  2.71it/s]
# Epoch: 2; train loss: 0.0840; validation loss: 0.0594
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 3; train loss: 0.0475; validation loss: 0.0442
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 4; train loss: 0.0404; validation loss: 0.0407
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 5; train loss: 0.0342; validation loss: 0.0348
# 100% 95/95 [00:35<00:00,  2.68it/s]
# Epoch: 6; train loss: 0.0312; validation loss: 0.0350
# 100% 95/95 [00:35<00:00,  2.69it/s]
# Epoch: 7; train loss: 0.0279; validation loss: 0.0312
# 100% 95/95 [00:35<00:00,  2.69it/s]
# Epoch: 8; train loss: 0.0257; validation loss: 0.0301
# 100% 95/95 [00:35<00:00,  2.66it/s]
# Epoch: 9; train loss: 0.0233; validation loss: 0.0299
# 100% 95/95 [00:35<00:00,  2.66it/s]
# Epoch: 10; train loss: 0.0217; validation loss: 0.0297
# 100% 95/95 [00:35<00:00,  2.69it/s]
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240414-034953_with_tumOnly.png)

# %% [markdown]
# ### Unet (Tumour Only) Segmentation Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_tumourOnly_test.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_3.png
# Average IoU for the test set: 0.4089
# Average F1 Score for the test set: 0.4973

# %% [markdown]
# picture illustration
# ![Original Image](saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_1.png) ![Ground Truth Mask](saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_2.png) ![Predicted Mask](saved_models/vanilla_unet_best_segmentation_wth_tumOnly.pth_3.png)

# %% [markdown]
# ## Unet (Tumour and non-Tomour) Segmentation

# %%
# !python training.py -c Configs/seg_vanilla_unet.json
# Out:
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 1; train loss: 0.2269; validation loss: 0.1572
# 100% 133/133 [00:46<00:00,  2.88it/s]
# Epoch: 2; train loss: 0.0464; validation loss: 0.0394
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 3; train loss: 0.0330; validation loss: 0.0328
# 100% 133/133 [00:46<00:00,  2.87it/s]
# Epoch: 4; train loss: 0.0283; validation loss: 0.0288
# 100% 133/133 [00:46<00:00,  2.86it/s]
# Epoch: 5; train loss: 0.0254; validation loss: 0.0262
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 6; train loss: 0.0237; validation loss: 0.0256
# 100% 133/133 [00:46<00:00,  2.86it/s]
# Epoch: 7; train loss: 0.0218; validation loss: 0.0247
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 8; train loss: 0.0200; validation loss: 0.0239
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 9; train loss: 0.0178; validation loss: 0.0254
# 100% 133/133 [00:46<00:00,  2.85it/s]
# Epoch: 10; train loss: 0.0163; validation loss: 0.0238
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240413-153903_without_tf_lrn.png)

# %% [markdown]
# ### Unet (Tumour and non-Tomour) Segmentation Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_notum.pth_3.png
# Average IoU for the test set: 0.5995
# Average F1 Score for the test set: 0.4340

# %% [markdown]
# picture illustration
# ![Original Image](saved_models/vanilla_unet_best_segmentation_wth_notum.pth_1.png) ![Ground Truth Mask](saved_models/vanilla_unet_best_segmentation_wth_notum.pth_2.png) ![Predicted Mask](saved_models/vanilla_unet_best_segmentation_wth_notum.pth_3.png)

# %% [markdown]
# ## Classification training

# %%
# !git pull
# !python training.py -c Configs/cls_vanilla_unet_gated.json
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 328 bytes | 328.00 KiB/s, done.
# From https://github.com/Oliverluyu/brain_tumor_img_segmentation
#    3f666fe..8736a3a  exp2_new   -> origin/exp2_new
# Updating 3f666fe..8736a3a
# Fast-forward
#  Configs/cls_vanilla_unet_gated.json | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Epoch: 1; train loss: 1.1863; validation loss: 0.5570
# Validation Accuracy: 79.25%
# Epoch: 2; train loss: 0.6399; validation loss: 0.6515
# Validation Accuracy: 74.76%
# Epoch: 3; train loss: 0.5490; validation loss: 0.5186
# Validation Accuracy: 79.61%
# Epoch: 4; train loss: 0.4861; validation loss: 0.4216
# Validation Accuracy: 84.22%
# Epoch: 5; train loss: 0.4509; validation loss: 0.3907
# Validation Accuracy: 85.56%
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240413-150120_classification.png)

# %% [markdown]
# ## Unet (Tumour Only) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_vanilla_unet_tumourOnly_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ### Unet (Tumour and non-Tomour) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_tumourOnly_transLearn_cls_layer_test.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.3855
# Average F1 Score for the test set: 0.4638

# %% [markdown]
# picture illustration
# ![Original Image](saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_1.png) ![Ground Truth Mask](saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_2.png) ![Predicted Mask](saved_models/vanilla_unet_best_segmentation_wth_tumOnly_with_transLearn_cls_layer.pth_3.png)

# %% [markdown]
# ## Unet (Tumour and non-Tomour) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_vanilla_unet_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ![alt text](saved_models/model_performance_20240413-234842_with_tf_lrn_layer.png)

# %% [markdown]
# ### Unet (Tumour and non-Tomour) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_vanilla_unet_transLearn_cls_layer.json
# Out:
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.6506
# Average F1 Score for the test set: 0.4775

# %% [markdown]
# picture illustration
# ![Original Image](saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png) ![Ground Truth Mask](saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png) ![Predicted Mask](saved_models/vanilla_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png)

# %% [markdown]
# ## Attention Unet (Tumour and non-Tomour) Segmentation

# %%
# !python training.py -c Configs/seg_unet_attention.json

# %% [markdown]
# ### Attention Unet (Tumour and non-Tomour) Segmentation

# %%
# !python testing.py -c Configs/seg_unet_attention.json

# %% [markdown]
# ## Attention Unet (Tumour and non-Tomour) Segmentation with Transfer Learning

# %%
# !python training.py -c Configs/seg_unet_attention_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ### Attention Unet (Tumour and non-Tomour) Segmentation with Transfer Learning Result

# %%
# !python testing.py -c Configs/seg_unet_attention_transLearn_cls_layer.json
# Out:
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.6902
# Average F1 Score for the test set: 0.5218

# %% [markdown]
# picture illustration
# ![Original Image](saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_1.png) ![Ground Truth Mask](saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_2.png) ![Predicted Mask](saved_models/Attention_unet_best_segmentation_with_transLearn_cls_layer.pth_3.png)
