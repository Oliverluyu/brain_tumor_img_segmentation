# %% [markdown]
# ## CMUNet with Multi-scale attention gate segmentation

# %%
# !python training.py -c Configs/cmunet_msag/seg_cmunet_msag.json
# Out:
# 100%|█████████████████████████████████████████| 133/133 [00:39<00:00,  3.35it/s]
# Epoch: 1; train loss: 0.5576; validation loss: 0.4630
# 100%|█████████████████████████████████████████| 133/133 [00:38<00:00,  3.47it/s]
# Epoch: 2; train loss: 0.0637; validation loss: 0.0394
# 100%|█████████████████████████████████████████| 133/133 [00:40<00:00,  3.29it/s]
# Epoch: 3; train loss: 0.0358; validation loss: 0.0336
# 100%|█████████████████████████████████████████| 133/133 [00:38<00:00,  3.45it/s]
# Epoch: 4; train loss: 0.0312; validation loss: 0.0310
# 100%|█████████████████████████████████████████| 133/133 [00:39<00:00,  3.34it/s]
# Epoch: 5; train loss: 0.0284; validation loss: 0.0298
# 100%|█████████████████████████████████████████| 133/133 [00:41<00:00,  3.20it/s]
# Epoch: 6; train loss: 0.0258; validation loss: 0.0284
# 100%|█████████████████████████████████████████| 133/133 [00:44<00:00,  2.98it/s]
# Epoch: 7; train loss: 0.0242; validation loss: 0.0254
# ...

# %% [markdown]
# ![model_performance_20240429-161056.png](attachment:2499bd3e-692f-469e-8b1b-26177d923726.png)

# %%
# !python testing.py -c Configs/cmunet_msag/seg_cmunet_msag.json
# Out:
# Saved visualization to saved_models/cmunet_msag_best_segmentation.pth_1.png
# Saved visualization to saved_models/cmunet_msag_best_segmentation.pth_2.png
# Saved visualization to saved_models/cmunet_msag_best_segmentation.pth_3.png
# Average IoU for the test set: 0.6810
# Average F1 Score for the test set: 0.5218
# Average Precision: 0.5502
# Average Recall/Sensitivity: 0.5327
# Average Specificity: 0.9973

# %% [markdown]
# ![cmunet_msag_best_segmentation.pth_1.png](attachment:c1bb2d68-c4e9-4a98-b732-c0970c47d8b7.png)
# ![cmunet_msag_best_segmentation.pth_2.png](attachment:0c6984ba-a653-4eac-a4da-9c6fa89a2898.png)
# ![cmunet_msag_best_segmentation.pth_3.png](attachment:f0fa6049-b0eb-477b-a6a6-3ce829dce7a9.png)

# %% [markdown]
# ## CMUNet cls

# %%
# !python training.py -c Configs/cmunet_msag/cls_cmunet_msag.json

# %% [markdown]
# ## CMUNet seg transfer learning

# %%
# !python training.py -c Configs/cmunet_msag/seg_cmunet_msag_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer conv1.conv1.0.weight
# Transferred layer conv1.conv1.0.bias
# Transferred layer conv1.conv1.1.weight
# Transferred layer conv1.conv1.1.bias
# Transferred layer conv1.conv1.1.running_mean
# Transferred layer conv1.conv1.1.running_var
# Transferred layer conv1.conv1.1.num_batches_tracked
# Transferred layer conv1.conv2.0.weight
# Transferred layer conv1.conv2.0.bias
# Transferred layer conv1.conv2.1.weight
# Transferred layer conv1.conv2.1.bias
# Transferred layer conv1.conv2.1.running_mean
# Transferred layer conv1.conv2.1.running_var
# Transferred layer conv1.conv2.1.num_batches_tracked
# Transferred layer conv2.conv1.0.weight
# Transferred layer conv2.conv1.0.bias
# Transferred layer conv2.conv1.1.weight
# Transferred layer conv2.conv1.1.bias
# Transferred layer conv2.conv1.1.running_mean
# Transferred layer conv2.conv1.1.running_var
# Transferred layer conv2.conv1.1.num_batches_tracked
# Transferred layer conv2.conv2.0.weight
# ...

# %% [markdown]
# ![model_performance_20240429-163548.png](attachment:88b338b9-2d1d-476a-9a3a-c3b055a9ee11.png)

# %%
# !python testing.py -c Configs/cmunet_msag/seg_cmunet_msag_transLearn_cls_layer.json
# Out:
# Saved visualization to saved_models/cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.6887
# Average F1 Score for the test set: 0.5114
# Average Precision: 0.6163
# Average Recall/Sensitivity: 0.5039
# Average Specificity: 0.9989

# %% [markdown]
# ![cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_1.png](attachment:93a69ded-67c0-44db-bb8d-5113ca12398c.png)
# ![cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_2.png](attachment:2044e806-a23c-40f4-903a-8c83c413c094.png)
# ![cmunet_msag_best_segmentation_with_transLearn_cls_layer.pth_3.png](attachment:c7d030f6-c894-4478-a27d-406c6af1a6c7.png)
