# %%
# !git clone https://github.com/Oliverluyu/brain_tumor_img_segmentation.git
# !pip install einops
# %cd brain_tumor_img_segmentation
# !git checkout master
# Out:
# Cloning into 'brain_tumor_img_segmentation'...
# remote: Enumerating objects: 13811, done.
# remote: Counting objects: 100% (662/662), done.
# remote: Compressing objects: 100% (331/331), done.
# remote: Total 13811 (delta 335), reused 626 (delta 331), pack-reused 13149
# Receiving objects: 100% (13811/13811), 2.30 GiB | 34.70 MiB/s, done.
# Resolving deltas: 100% (889/889), done.
# Updating files: 100% (15775/15775), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 875.2 kB/s eta 0:00:00
# ...
# /content/brain_tumor_img_segmentation
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %% [markdown]
# unfreeze tf learning

# %%
# !python training.py -c Configs/seg_unet_proposed_unet_transferLrn.json
# Out:
# applying transfer learning
# Transferred layer init_conv.weight
# Transferred layer init_conv.bias
# Transferred layer downs.0.0.block1.proj.weight
# Transferred layer downs.0.0.block1.proj.bias
# Transferred layer downs.0.0.block1.norm.weight
# Transferred layer downs.0.0.block1.norm.bias
# Transferred layer downs.0.0.block2.proj.weight
# Transferred layer downs.0.0.block2.proj.bias
# Transferred layer downs.0.0.block2.norm.weight
# Transferred layer downs.0.0.block2.norm.bias
# Transferred layer downs.0.1.block1.proj.weight
# Transferred layer downs.0.1.block1.proj.bias
# Transferred layer downs.0.1.block1.norm.weight
# Transferred layer downs.0.1.block1.norm.bias
# Transferred layer downs.0.1.block2.proj.weight
# Transferred layer downs.0.1.block2.proj.bias
# Transferred layer downs.0.1.block2.norm.weight
# Transferred layer downs.0.1.block2.norm.bias
# Transferred layer downs.0.2.fn.fn.to_qkv.weight
# Transferred layer downs.0.2.fn.fn.to_out.0.weight
# ...

# %%
# !python testing.py -c Configs/seg_unet_proposed_unet_transferLrn_unfreeze.json
# Out:
# Saved visualization to saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_1.png
# Saved visualization to saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_2.png
# Saved visualization to saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_3.png
# Average IoU for the test set: 0.7642
# Average F1 Score for the test set: 0.5923
# Average Precision: 0.5639
# Average Recall/Sensitivity: 0.6639
# Average Specificity: 0.9969

# %% [markdown]
# ![alt text](saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_1.png)
# ![alt text](saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_2.png)
# ![alt text](saved_models/Proposed_attention_unet_convmixer_best_segmentation_transferlrn_unfreeze.pth_3.png)
