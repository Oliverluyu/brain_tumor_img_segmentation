# %% [markdown]
# ## CMUNeXt  segmentation

# %%
# !python training.py -c Configs/cmuneXt/seg_cmuneXt.json
# Out:
#   0%|                                                   | 0/133 [00:00<?, ?it/s]/root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# 100%|█████████████████████████████████████████| 133/133 [00:45<00:00,  2.90it/s]
# Epoch: 1; train loss: 0.4737; validation loss: 0.3741
# 100%|█████████████████████████████████████████| 133/133 [00:44<00:00,  2.99it/s]
# Epoch: 2; train loss: 0.3555; validation loss: 0.3470
# 100%|█████████████████████████████████████████| 133/133 [00:44<00:00,  3.01it/s]
# Epoch: 3; train loss: 0.3318; validation loss: 0.3490
# 100%|█████████████████████████████████████████| 133/133 [00:44<00:00,  3.00it/s]
# Epoch: 4; train loss: 0.3224; validation loss: 0.4662
# ...

# %% [markdown]
# ![model_performance_20240430-011417.png](attachment:17e094f9-6e86-451a-88e3-2a99175b355b.png)

# %%
# !python testing.py -c Configs/cmuneXt/seg_cmuneXt.json
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# Saved visualization to saved_models/cmuneXt_best_segmentation.pth_1.png
# Saved visualization to saved_models/cmuneXt_best_segmentation.pth_2.png
# Saved visualization to saved_models/cmuneXt_best_segmentation.pth_3.png
# Average IoU for the test set: 0.7191
# Average F1 Score for the test set: 0.6026
# Average Precision: 0.6077
# Average Recall/Sensitivity: 0.6247
# Average Specificity: 0.9966

# %% [markdown]
# ## lr=1e-3

# %%
# !python training.py -c Configs/cmuneXt/seg_cmuneXt_1e-4.json
# Out:
#   0%|                                                   | 0/133 [00:00<?, ?it/s]/root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# 100%|█████████████████████████████████████████| 133/133 [00:44<00:00,  2.96it/s]
# Epoch: 1; train loss: 0.7004; validation loss: 0.6043
# 100%|█████████████████████████████████████████| 133/133 [00:43<00:00,  3.04it/s]
# Epoch: 2; train loss: 0.5356; validation loss: 0.4824
# 100%|█████████████████████████████████████████| 133/133 [00:43<00:00,  3.03it/s]
# Epoch: 3; train loss: 0.4169; validation loss: 0.4056
# 100%|█████████████████████████████████████████| 133/133 [00:43<00:00,  3.06it/s]
# Epoch: 4; train loss: 0.3397; validation loss: 0.3315
# ...

# %% [markdown]
# ![model_performance_20240430-013838.png](attachment:0a678dd9-2eca-4339-bb76-3014e6203bbf.png)

# %%
# !python testing.py -c Configs/cmuneXt/seg_cmuneXt_1e-4.json
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# Saved visualization to saved_models/cmuneXt_1e-4_best_segmentation.pth_1.png
# Saved visualization to saved_models/cmuneXt_1e-4_best_segmentation.pth_2.png
# Saved visualization to saved_models/cmuneXt_1e-4_best_segmentation.pth_3.png
# Average IoU for the test set: 0.7377
# Average F1 Score for the test set: 0.6158
# Average Precision: 0.6420
# Average Recall/Sensitivity: 0.6111
# Average Specificity: 0.9982

# %% [markdown]
# ## CMUNeXt  cls

# %%
# !python training.py -c Configs/cmuneXt/cls_cmuneXt.json
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# Epoch: 1; train loss: 1.9446; validation loss: 0.5982
# Validation Accuracy: 78.28%
# Epoch: 2; train loss: 1.2579; validation loss: 0.4821
# Validation Accuracy: 83.62%
# Epoch: 3; train loss: 1.0061; validation loss: 0.3820
# Validation Accuracy: 88.59%
# Epoch: 4; train loss: 0.8340; validation loss: 0.3770
# Validation Accuracy: 87.38%
# Epoch: 5; train loss: 0.7058; validation loss: 0.3438
# Validation Accuracy: 88.83%
# Epoch: 6; train loss: 0.5793; validation loss: 0.3381
# Validation Accuracy: 88.71%
# Epoch: 7; train loss: 0.4746; validation loss: 0.3642
# Validation Accuracy: 84.71%
# Epoch: 8; train loss: 0.4200; validation loss: 0.2948
# ...

# %% [markdown]
# ## CMUNet seg transfer learning

# %%
# !python training.py -c Configs/cmuneXt/seg_cmuneXt_transLearn_cls_layer.json
# Out:
# applying transfer learning
# Transferred layer stem.conv.0.weight
# Transferred layer stem.conv.0.bias
# Transferred layer stem.conv.1.weight
# Transferred layer stem.conv.1.bias
# Transferred layer stem.conv.1.running_mean
# Transferred layer stem.conv.1.running_var
# Transferred layer stem.conv.1.num_batches_tracked
# Transferred layer encoder1.block.0.0.fn.0.weight
# Transferred layer encoder1.block.0.0.fn.0.bias
# Transferred layer encoder1.block.0.0.fn.2.weight
# Transferred layer encoder1.block.0.0.fn.2.bias
# Transferred layer encoder1.block.0.0.fn.2.running_mean
# Transferred layer encoder1.block.0.0.fn.2.running_var
# Transferred layer encoder1.block.0.0.fn.2.num_batches_tracked
# Transferred layer encoder1.block.0.1.weight
# Transferred layer encoder1.block.0.1.bias
# Transferred layer encoder1.block.0.3.weight
# Transferred layer encoder1.block.0.3.bias
# Transferred layer encoder1.block.0.3.running_mean
# Transferred layer encoder1.block.0.3.running_var
# ...

# %% [markdown]
# ![model_performance_20240430-143439.png](attachment:1ba194e7-b8fa-43a8-826a-95dd387b2608.png)

# %%
# !python testing.py -c Configs/cmuneXt/seg_cmuneXt_transLearn_cls_layer.json
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_1.png
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_2.png
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_3.png
# Average IoU for the test set: 0.8096
# Average F1 Score for the test set: 0.6355
# Average Precision: 0.6408
# Average Recall/Sensitivity: 0.6407
# Average Specificity: 0.9985

# %% [markdown]
# ![cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_1.png](attachment:9018b5d4-a1f6-4226-a911-e065d24487e8.png)
# ![cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_2.png](attachment:909e02e1-01f6-4df8-ba77-fdcd2c97fd36.png)
# ![cmuneXt_best_segmentation_with_transLearn_cls_layer.pth_3.png](attachment:c80a98ca-7438-42ff-ac31-8734e83c9270.png)

# %% [markdown]
# ## epoch 30

# %%
# !python training.py -c Configs/cmunet_msag/seg_cmunet_msag_transLearn_cls_layer.json

# %%
# !python testing.py -c Configs/cmunet_msag/seg_cmunet_msag_transLearn_cls_layer.json

# %% [markdown]
# ## CMUNeXt seg transfer learning partial freeze

# %%
# !python training.py -c Configs/cmuneXt/seg_cmuneXt_transLearn_partial_freeze.json
# Out:
# applying transfer learning
# Transferred layer stem.conv.0.weight
# Transferred layer stem.conv.0.bias
# Transferred layer stem.conv.1.weight
# Transferred layer stem.conv.1.bias
# Transferred layer stem.conv.1.running_mean
# Transferred layer stem.conv.1.running_var
# Transferred layer stem.conv.1.num_batches_tracked
# Transferred layer encoder1.block.0.0.fn.0.weight
# Transferred layer encoder1.block.0.0.fn.0.bias
# Transferred layer encoder1.block.0.0.fn.2.weight
# Transferred layer encoder1.block.0.0.fn.2.bias
# Transferred layer encoder1.block.0.0.fn.2.running_mean
# Transferred layer encoder1.block.0.0.fn.2.running_var
# Transferred layer encoder1.block.0.0.fn.2.num_batches_tracked
# Transferred layer encoder1.block.0.1.weight
# Transferred layer encoder1.block.0.1.bias
# Transferred layer encoder1.block.0.3.weight
# Transferred layer encoder1.block.0.3.bias
# Transferred layer encoder1.block.0.3.running_mean
# Transferred layer encoder1.block.0.3.running_var
# ...

# %% [markdown]
# ![model_performance_20240430-145307.png](attachment:82f15dea-5d31-4b8f-9dbd-82950f9b5305.png)

# %%
# !python testing.py -c Configs/cmuneXt/seg_cmuneXt_transLearn_partial_freeze.json
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_1.png
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_2.png
# Saved visualization to saved_models/cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_3.png
# Average IoU for the test set: 0.7488
# Average F1 Score for the test set: 0.5867
# Average Precision: 0.5834
# Average Recall/Sensitivity: 0.6110
# Average Specificity: 0.9968

# %% [markdown]
# ![cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_1.png](attachment:421b1819-870d-469a-a7bb-ca96da6a9de8.png)
# ![cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_2.png](attachment:ece5e4e8-0de9-4b1c-93ca-b852fef805e1.png)
# ![cmuneXt_best_segmentation_with_transLearn_partial_freeze.pth_3.png](attachment:2f48a962-0626-4a84-ac4a-a2a6e6957447.png)
